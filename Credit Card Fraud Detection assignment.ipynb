# %% [markdown]
# # Credit Card Fraud Detection::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# # Description about dataset::

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
#
# ### Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# # WORKFLOW :

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Standardized the Input Variables.
#
# 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# 7.Train the Model with Epochs (100).
#
# 8.If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
#
# 9.Prediction should be > 92%
# 10.Evaluation Step
# 11Prediction

# %% [markdown]
# # Task::

# %% [markdown]
# ## Identify fraudulent credit card transactions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv('C:\\Users\\lenovo\\Desktop\\ASSIGNEMENT\\DLAssignments\\Data\\creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# # 2.Checking Missing Values

# %%
data.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
np.where(data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# # 3.Standardized the Input Variables.

# %%
data.reset_index(drop=True, inplace=True)
labels = data.pop('Class') # Pop function will removes 'Class' from data and returns which is saved in labels

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
data -= data.mean()
data /= data.std()

# %%
data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.137547e-15 -2.369347e-15 -9.299088e-17  6.265771e-15  1.966167e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.996580e+00 -2.879850e+01 -4.403521e+01 -3.187168e+01 -4.013912e+00
# 25%   -8.552105e-01 -4.698909e-01 -3.624701e-01 -5.872131e-01 -5.993777e-01
# 50%   -2.131450e-01  9.245335e-03  3.965677e-02  1.186122e-01 -1.401721e-02
# 75%    9.372158e-01  6.716927e-01  4.867194e-01  6.774557e-01  5.250073e-01
# max    1.642055e+00  1.253349e+00  1.335773e+01  6.187982e+00  1.191872e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.757901e-15 -2.227124e-16  1.663279e-15  2.504277e-16  1.113356e-15
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -8.240795e+01 -1.963602e+01 -3.520933e+01 -6.130242e+01 -1.222799e+01
# 25%   -5.010677e-01 -5.766811e-01 -4.478852e-01 -1.746801e-01 -5.853621e-01
# 50%   -3.936675e-02 -2.058043e-01  3.241718e-02  1.871979e-02 -4.681161e-02
# 75%    4.433457e-01  2.991620e-01  4.611099e-01  2.740780e-01  5.435296e-01
# max    2.521409e+01  5.502005e+01  9.747807e+01  1.675150e+01  1.419492e+01
#
#        ...           V20           V21           V22           V23  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  6.157864e-16  1.850826e-17 -2.630385e-15 -7.445328e-16
# std    ...  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min    ... -7.069134e+01 -4.741898e+01 -1.506562e+01 -7.175434e+01
# 25%    ... -2.746329e-01 -3.109428e-01 -7.473463e-01 -2.591780e-01
# 50%    ... -8.104691e-02 -4.009422e-02  9.345360e-03 -1.792417e-02
# 75%    ...  1.725730e-01  2.537387e-01  7.283347e-01  2.364315e-01
# max    ...  5.113455e+01  3.703465e+01  1.447302e+01  3.607661e+01
#
#                 V24           V25           V26           V27           V28  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   7.621335e-17 -1.055018e-15 -1.504105e-16  2.448796e-17 -3.725646e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -4.683630e+00 -1.975030e+01 -5.401088e+00 -5.590650e+01 -4.674604e+01
# 25%   -5.854666e-01 -6.083990e-01 -6.780705e-01 -1.755050e-01 -1.604437e-01
# 50%    6.765666e-02  3.183234e-02 -1.081215e-01  3.325168e-03  3.406362e-02
# 75%    7.257141e-01  6.727994e-01  4.996654e-01  2.255644e-01  2.371521e-01
# max    7.569671e+00  1.442529e+01  7.293962e+00  7.831926e+01  1.025432e+02
#
#              Amount
# count  2.848070e+05
# mean   2.278134e-13
# std    1.000000e+00
# min   -3.532288e-01
# 25%   -3.308395e-01
# 50%   -2.652710e-01
# 75%   -4.471699e-02
# max    1.023621e+02
#
# [8 rows x 30 columns]

# %% [markdown]
# # 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).

# %%
data_len = len(data)
train_data = data.iloc[:data_len*50//100]
val_data = data.iloc[data_len*50//100:data_len*70//100]
test_data = data.iloc[data_len*70//100:]
labels_len = len(labels)
train_labels = labels.iloc[:labels_len*50//100]
val_labels = labels.iloc[labels_len*50//100:labels_len*70//100]
test_labels = labels.iloc[labels_len*70//100:]

# %% [markdown]
# # # 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).

# %% [markdown]
# # 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# # 7.Train the Model with Epochs (100).

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
import tensorflow as tf

network = models.Sequential()
network.add(layers.Dense(10,activation='tanh',input_shape=(len(train_data.columns),) ))
network.add(layers.Dense(8,activation='tanh',input_shape=(data.shape[1],) ))
network.add(layers.Dense(6,activation='tanh',input_shape=(data.shape[1],) ))
network.add(layers.Dense(1,activation="sigmoid"))
network.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
with tf.device('/device:GPU:1'):
  # %time MODEL = network.fit(train_data,train_labels,epochs=50,batch_size=256,validation_data=(val_data,val_labels))
# Out:
# Epoch 1/50
# 557/557 [==============================] - 4s 5ms/step - loss: 0.2364 - acc: 0.9264 - val_loss: 0.7781 - val_acc: 0.7078
# Epoch 2/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0049 - acc: 0.9992 - val_loss: 0.7681 - val_acc: 0.7475
# Epoch 3/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0037 - acc: 0.9992 - val_loss: 0.7079 - val_acc: 0.7817
# Epoch 4/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0030 - acc: 0.9994 - val_loss: 0.5671 - val_acc: 0.8285
# Epoch 5/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0027 - acc: 0.9994 - val_loss: 0.4966 - val_acc: 0.8454
# Epoch 6/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0029 - acc: 0.9994 - val_loss: 0.4143 - val_acc: 0.8647
# Epoch 7/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0025 - acc: 0.9995 - val_loss: 0.3459 - val_acc: 0.8810
# Epoch 8/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0031 - acc: 0.9995 - val_loss: 0.2742 - val_acc: 0.9004
# Epoch 9/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0031 - acc: 0.9995 - val_loss: 0.2488 - val_acc: 0.9101
# Epoch 10/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 0.2165 - val_acc: 0.9200
# Epoch 11/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0028 - acc: 0.9995 - val_loss: 0.1896 - val_acc: 0.9296
# Epoch 12/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0027 - acc: 0.9995 - val_loss: 0.1770 - val_acc: 0.9333
# Epoch 13/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0028 - acc: 0.9995 - val_loss: 0.1766 - val_acc: 0.9333
# Epoch 14/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0030 - acc: 0.9995 - val_loss: 0.1192 - val_acc: 0.9528
# Epoch 15/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0025 - acc: 0.9995 - val_loss: 0.1135 - val_acc: 0.9531
# Epoch 16/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0023 - acc: 0.9995 - val_loss: 0.0961 - val_acc: 0.9614
# Epoch 17/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0027 - acc: 0.9996 - val_loss: 0.0870 - val_acc: 0.9657
# Epoch 18/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0021 - acc: 0.9995 - val_loss: 0.0829 - val_acc: 0.9672
# Epoch 19/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0027 - acc: 0.9996 - val_loss: 0.1041 - val_acc: 0.9620
# Epoch 20/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0027 - acc: 0.9996 - val_loss: 0.0745 - val_acc: 0.9718
# Epoch 21/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0031 - acc: 0.9995 - val_loss: 0.0981 - val_acc: 0.9627
# Epoch 22/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0025 - acc: 0.9995 - val_loss: 0.1170 - val_acc: 0.9566
# Epoch 23/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0021 - acc: 0.9996 - val_loss: 0.0817 - val_acc: 0.9702
# Epoch 24/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0020 - acc: 0.9996 - val_loss: 0.0772 - val_acc: 0.9723
# Epoch 25/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0020 - acc: 0.9996 - val_loss: 0.0675 - val_acc: 0.9763
# Epoch 26/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0795 - val_acc: 0.9723
# Epoch 27/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0024 - acc: 0.9996 - val_loss: 0.0807 - val_acc: 0.9709
# Epoch 28/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0022 - acc: 0.9996 - val_loss: 0.0672 - val_acc: 0.9768
# Epoch 29/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0017 - acc: 0.9997 - val_loss: 0.0801 - val_acc: 0.9713
# Epoch 30/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0022 - acc: 0.9996 - val_loss: 0.0730 - val_acc: 0.9736
# Epoch 31/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0027 - acc: 0.9995 - val_loss: 0.0886 - val_acc: 0.9683
# Epoch 32/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0024 - acc: 0.9996 - val_loss: 0.0524 - val_acc: 0.9819
# Epoch 33/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0024 - acc: 0.9996 - val_loss: 0.0709 - val_acc: 0.9759
# Epoch 34/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0022 - acc: 0.9996 - val_loss: 0.0683 - val_acc: 0.9769
# Epoch 35/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 0.0626 - val_acc: 0.9786
# Epoch 36/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0025 - acc: 0.9996 - val_loss: 0.0749 - val_acc: 0.9742
# Epoch 37/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0024 - acc: 0.9995 - val_loss: 0.0727 - val_acc: 0.9748
# Epoch 38/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0017 - acc: 0.9997 - val_loss: 0.0877 - val_acc: 0.9701
# Epoch 39/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0020 - acc: 0.9997 - val_loss: 0.0742 - val_acc: 0.9743
# Epoch 40/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0020 - acc: 0.9997 - val_loss: 0.0629 - val_acc: 0.9792
# Epoch 41/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0631 - val_acc: 0.9794
# Epoch 42/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0022 - acc: 0.9996 - val_loss: 0.0640 - val_acc: 0.9789
# Epoch 43/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 0.0679 - val_acc: 0.9772
# Epoch 44/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0022 - acc: 0.9997 - val_loss: 0.1112 - val_acc: 0.9592
# Epoch 45/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0020 - acc: 0.9997 - val_loss: 0.1012 - val_acc: 0.9620
# Epoch 46/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 0.0768 - val_acc: 0.9722
# Epoch 47/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0021 - acc: 0.9996 - val_loss: 0.0841 - val_acc: 0.9686
# Epoch 48/50
# 557/557 [==============================] - 2s 3ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 0.0786 - val_acc: 0.9707
# Epoch 49/50
# 206/557 [==========>...................] - ETA: 0s - loss: 0.0018 - acc: 0.9997

# %%
test_loss , test_acc = network.evaluate(test_data,test_labels)

# %%
test_labels[test_labels == 1]

# %%
history_dict = MODEL.history
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']
epoches = np.arange(1,len(history_dict['acc'])+1)
plt.plot(epoches,acc_values,'bo',label="Training Accuracy")
plt.plot(epoches,val_acc_values,'b',label="Validation Accuracy")
plt.title('Training and validation Accuracy')
plt.xlabel("Epoches")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# # Trying with Relu

# %%
network1 = models.Sequential()
network1.add(layers.Dense(10,activation='relu',input_shape=(len(train_data.columns),) ))
network1.add(layers.Dense(8,activation='relu',input_shape=(data.shape[1],) ))
network1.add(layers.Dense(6,activation='relu',input_shape=(data.shape[1],) ))
network1.add(layers.Dense(1,activation="sigmoid"))
network1.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
with tf.device('/device:GPU:1'):
  # %time MODEL1 = network1.fit(train_data,train_labels,epochs=10,batch_size=256,validation_data=(val_data,val_labels))

# %% [markdown]
# # 10. Evaluation

# %%
test_loss , test_acc = network1.evaluate(test_data,test_labels)

# %%
history_dict = MODEL1.history
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']
epoches = np.arange(1,len(history_dict['acc'])+1)
plt.plot(epoches,acc_values,'bo',label="Training Accuracy")
plt.plot(epoches,val_acc_values,'b',label="Validation Accuracy")
plt.title('Training and validation Accuracy')
plt.xlabel("Epoches")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # 11. Prediction

# %%
predictions = network1.predict(test_data)
correct_prediction = np.argmax(predictions) == np.array(test_labels)
print(f"{len(correct_prediction)} out of {len(predictions)} ")

# %%
test_acc

# %%
# Relu has given best accuracy with least epochs
